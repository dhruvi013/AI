# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruvi013/AI/blob/main/Basics_of_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text="I am learning AI programming and the module is Natural language processing"

# %%
words=text.split()
word=[w.lower() for w in words]
word
# Out:
# ['i',
#  'am',
#  'learning',
#  'ai',
#  'programming',
#  'and',
#  'the',
#  'module',
#  'is',
#  'natural',
#  'language',
#  'processing']

# %%
text[5]
# Out:
# 'l'

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
type(text)
# Out:
# str

# %%
doc=nlp(text)

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
doc[5]
# Out:
# and

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
doc
# Out:
# I am learning AI programming and the module is Natural language processing

# %%
words
# Out:
# ['I',
#  'am',
#  'learning',
#  'AI',
#  'programming',
#  'and',
#  'the',
#  'module',
#  'is',
#  'Natural',
#  'language',
#  'processing']

# %%
"".join(words)
# Out:
# 'IamlearningAIprogrammingandthemoduleisNaturallanguageprocessing'

# %%
"".join(words)[5]
# Out:
# 'a'

# %%
text1="My name is Dhruvi. I am learning AI in Marwadi University from 9.30 onwards in MA112."

# %%
doc=nlp(text1)

# %%
for token in doc.ents:
  print(token,token.label_)
# Out:
# Dhruvi PERSON
# AI ORG
# Marwadi University ORG
# 9.30 CARDINAL
# MA112 GPE

# %%
#dependency parsing
text3="Apple is building a factory at U.K. for $6 million."

# %%
doc=nlp(text3)

# %%
from spacy import displacy
displacy.render(doc,style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="99e8e487d661434aad689bc420b98d0d-0" class="displacy" width="1975" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
#POS tags -> part of speech tags
import nltk
nltk.download('averaged_perception_tagger')
# Out:
# [nltk_data] Error loading averaged_perception_tagger: Package
# [nltk_data]     'averaged_perception_tagger' not found in index
# False

# %%
text
# Out:
# 'I am learning AI programming and the module is Natural language processing'

# %%
doc=nlp(text)

# %%
for token in doc:
  print(token,token.pos_)
# Out:
# I PRON
# am AUX
# learning VERB
# AI PROPN
# programming NOUN
# and CCONJ
# the DET
# module NOUN
# is AUX
# Natural ADJ
# language NOUN
# processing NOUN

# %%
#STEMMING VS LEMMATIZATION
text="I studied the subject named AI and then meeting Mr. Kohli tomorrow at the meeting"

# %%
text
# Out:
# 'I studied the subject named AI and then meeting Mr. Kohli tomorrow at the meeting'

# %%
from nltk.stem.porter import *

# %%
stemmer=PorterStemmer()
for word in text.split():
  print(word,"--> ",stemmer.stem(word))
# Out:
# I -->  i
# studied -->  studi
# the -->  the
# subject -->  subject
# named -->  name
# AI -->  ai
# and -->  and
# then -->  then
# meeting -->  meet
# Mr. -->  mr.
# Kohli -->  kohli
# tomorrow -->  tomorrow
# at -->  at
# the -->  the
# meeting -->  meet

# %%
for token in nlp(text):
  print(token,": ", token.pos_,"--> ",token.lemma_)
# Out:
# I :  PRON -->  I
# studied :  VERB -->  study
# the :  DET -->  the
# subject :  NOUN -->  subject
# named :  VERB -->  name
# AI :  PROPN -->  AI
# and :  CCONJ -->  and
# then :  ADV -->  then
# meeting :  VERB -->  meet
# Mr. :  PROPN -->  Mr.
# Kohli :  PROPN -->  Kohli
# tomorrow :  NOUN -->  tomorrow
# at :  ADP -->  at
# the :  DET -->  the
# meeting :  NOUN -->  meeting
